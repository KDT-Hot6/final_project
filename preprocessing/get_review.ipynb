# %%
import pandas as pd

# %%
dining_df = df = pd.read_csv('./review_final.csv')
dining_df
# Out:
#        Unnamed: 0   식당이름                      주소   평점  공감수  \
# 0               0  육회자매집      서울특별시 종로구 종로4가 177  4.3    7
# 1               1  육회자매집      서울특별시 종로구 종로4가 177  5.0    3
# 2               2  육회자매집      서울특별시 종로구 종로4가 177  5.0    2
# 3               3  육회자매집      서울특별시 종로구 종로4가 177  3.7   13
# 4               4  육회자매집      서울특별시 종로구 종로4가 177  3.0    4
# ...           ...    ...                     ...  ...  ...
# 62839       77861    팔각동  서울특별시 송파구 방이동 105-7 1층  5.0    4
# 62840       77862    팔각동  서울특별시 송파구 방이동 105-7 1층  5.0    4
# 62841       77863    팔각동  서울특별시 송파구 방이동 105-7 1층  3.7    2
# 62842       77864    팔각동  서울특별시 송파구 방이동 105-7 1층  4.3    2
# 62843       77865    팔각동  서울특별시 송파구 방이동 105-7 1층  5.0    2
#
#                                                       특징  \
# 0      저녁식사 술모임 점심식사 데이트 식사모임 가족외식 회식 혼밥 간식 혼술 아이동반 기...
# 1      저녁식사 술모임 점심식사 데이트 식사모임 가족외식 회식 혼밥 간식 혼술 아이동반 기...
# 2      저녁식사 술모임 점심식사 데이트 식사모임 가족외식 회식 혼밥 간식 혼술 아이동반 기...
# 3      저녁식사 술모임 점심식사 데이트 식사모임 가족외식 회식 혼밥 간식 혼술 아이동반 기...
# 4      저녁식사 술모임 점심식사 데이트 식사모임 가족외식 회식 혼밥 간식 혼술 아이동반 기...
# ...                                                  ...
# 62839  저녁식사 점심식사 데이트 혼밥 가족외식 식사모임 조용한 캐주얼한 깔끔한 이국적/이색...
# 62840  저녁식사 점심식사 데이트 혼밥 가족외식 식사모임 조용한 캐주얼한 깔끔한 이국적/이색...
# 62841  저녁식사 점심식사 데이트 혼밥 가족외식 식사모임 조용한 캐주얼한 깔끔한 이국적/이색...
# 62842  저녁식사 점심식사 데이트 혼밥 가족외식 식사모임 조용한 캐주얼한 깔끔한 이국적/이색...
# 62843  저녁식사 점심식사 데이트 혼밥 가족외식 식사모임 조용한 캐주얼한 깔끔한 이국적/이색...
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 62839  주말기준 30분 웨이팅했구요소규모인데다가 1인 쉐프운영이라빠른 회전률 기대하기 어렵...
# 62840  작은가게이어서 웨이팅이 있을수도 있을거같아요 이미 동네주민들한테 소문나서 혼밥하러도...
# 62841  인스타 갬성의 식당이라 가보았는데맛은 나쁘지 않았어요 그냥 한번 가볼만한 정도!내부...
# 62842                  음식들이 다 특이하고 맛있습니다. 또 갈 의향 있어요. ㅎㅎ
# 62843  방이동 중식당의 보물...혼자만 알고싶을 정도의 맛집...메뉴구성이 풍부하지 않아 ...
#
# [62844 rows x 7 columns]

# %%
dining_df.drop(['Unnamed: 0','평점','공감수','특징'], axis = 'columns', inplace=True)

# %%
dining_df = df
dining_df
# Out:
#         식당이름                      주소  \
# 0      육회자매집      서울특별시 종로구 종로4가 177
# 1      육회자매집      서울특별시 종로구 종로4가 177
# 2      육회자매집      서울특별시 종로구 종로4가 177
# 3      육회자매집      서울특별시 종로구 종로4가 177
# 4      육회자매집      서울특별시 종로구 종로4가 177
# ...      ...                     ...
# 62839    팔각동  서울특별시 송파구 방이동 105-7 1층
# 62840    팔각동  서울특별시 송파구 방이동 105-7 1층
# 62841    팔각동  서울특별시 송파구 방이동 105-7 1층
# 62842    팔각동  서울특별시 송파구 방이동 105-7 1층
# 62843    팔각동  서울특별시 송파구 방이동 105-7 1층
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 62839  주말기준 30분 웨이팅했구요소규모인데다가 1인 쉐프운영이라빠른 회전률 기대하기 어렵...
# 62840  작은가게이어서 웨이팅이 있을수도 있을거같아요 이미 동네주민들한테 소문나서 혼밥하러도...
# 62841  인스타 갬성의 식당이라 가보았는데맛은 나쁘지 않았어요 그냥 한번 가볼만한 정도!내부...
# 62842                  음식들이 다 특이하고 맛있습니다. 또 갈 의향 있어요. ㅎㅎ
# 62843  방이동 중식당의 보물...혼자만 알고싶을 정도의 맛집...메뉴구성이 풍부하지 않아 ...
#
# [62844 rows x 3 columns]

# %%
yonsei_df = pd.read_csv('./연세대.csv', encoding='cp949')
yonsei_df
# Out:
#        Column1   Restaurant UserID  \
# 0            0     흥부찜닭-신촌점  hs**님
# 1            1     흥부찜닭-신촌점  da**님
# 2            2     흥부찜닭-신촌점  fy**님
# 3            3     흥부찜닭-신촌점  23**님
# 4            4     흥부찜닭-신촌점  ey**님
# ...        ...          ...    ...
# 34520    34520  라화쿵부마라탕-신촌점  an**님
# 34521    34521  라화쿵부마라탕-신촌점  ww**님
# 34522    34522  라화쿵부마라탕-신촌점  HX**님
# 34523    34523  라화쿵부마라탕-신촌점     손님
# 34524    34524  라화쿵부마라탕-신촌점     손님
#
#                                                     Menu  \
# 0                          흥부 간장찜닭 （순살）/1(맛 선택(2단계 기본맛))
# 1                  흥부 간장찜닭 （순살）/1(맛 선택(2단계 기본맛)),참치마요밥/1
# 2                          흥부 간장찜닭 （순살）/1(맛 선택(2단계 기본맛))
# 3             흥부 간장찜닭 （한마리）/1(맛 선택(1단계 순한맛)),콜라 500ml¸/1
# 4               곱도리탕（한마리）/1(맛 선택(1단계 순한맛),순살 변경(순살로 변경))
# ...                                                  ...
# 34520   마라탕/1(사이즈선택(1인분),맛 선택(중간 매운맛（추천）),추가선택(소고기100g))
# 34521  마라샹궈/1(사이즈선택(소（小）),맛 선택(중간 매운맛（추천）),추가선택(건두부,공...
# 34522                 마라탕/1(사이즈선택(1인분),맛 선택(중간 매운맛（추천）))
# 34523                 마라탕/1(사이즈선택(1인분),맛 선택(중간 매운맛（추천）))
# 34524             마라샹궈/1(사이즈선택(소（小）),맛 선택(약간 매운맛（위마위라）))
#
#                                                   Review  Total  Taste  \
# 0                                       기본맛 맛있게맵고 양도 많네요      5    5.0
# 1                                           가성비 만족스럽네요 ㅎ      5    5.0
# 2      재료 상태도 좋고 맛도 적당히 매콤해서 좋아요 당면도 중국식당면 좋아하는디 맛있네요...      5    5.0
# 3                                             맛있어요~~~~~~      5    5.0
# 4                          곱창에 닭 맛있게 잘 먹었는데 양은 좀 아쉬웠습니다.      5    5.0
# ...                                                  ...    ...    ...
# 34520                              가게에서 먹던거랑 맛이 똑 같애요 ??      5    5.0
# 34521                                     11111111111111      5    5.0
# 34522                          국물 하고 야채 따로 따로 보장했어요.좋았어요      5    5.0
# 34523                                       量太少！！！！！！！！！      1    1.0
# 34524                                   양이 적고 덜 볶여서 맛없다.      1    1.0
#
#        Quantity  Delivery           Date  OperationTime                Address
# 0           5.0       4.0         23시간 전  15:21 - 22:00   서울 서대문구 창천동 33-43 2층
# 1           5.0       5.0             어제  15:21 - 22:00   서울 서대문구 창천동 33-43 2층
# 2           5.0       5.0           5일 전  15:21 - 22:00   서울 서대문구 창천동 33-43 2층
# 3           5.0       5.0   2021년 2월 16일  15:21 - 22:00   서울 서대문구 창천동 33-43 2층
# 4           4.0       5.0    2021년 2월 3일  15:21 - 22:00   서울 서대문구 창천동 33-43 2층
# ...         ...       ...            ...            ...                    ...
# 34520       5.0       5.0   2020년 6월 10일  10:30 - 22:00  서울 서대문구 창천동 52-5 1,2층
# 34521       5.0       5.0   2020년 5월 16일  10:30 - 22:00  서울 서대문구 창천동 52-5 1,2층
# 34522       5.0       5.0   2020년 3월 16일  10:30 - 22:00  서울 서대문구 창천동 52-5 1,2층
# 34523       1.0       1.0  2019년 10월 25일  10:30 - 22:00  서울 서대문구 창천동 52-5 1,2층
# 34524       1.0       4.0   2019년 6월 12일  10:30 - 22:00  서울 서대문구 창천동 52-5 1,2층
#
# [34525 rows x 12 columns]

# %%
yonsei_df.drop(['Column1', 'UserID', 'Menu', 'Total', 'Taste', 'Quantity', 'Delivery', 'Date', 'OperationTime'], axis='columns', inplace=True)
yonsei_df
# Out:
#         Restaurant                                             Review  \
# 0         흥부찜닭-신촌점                                   기본맛 맛있게맵고 양도 많네요
# 1         흥부찜닭-신촌점                                       가성비 만족스럽네요 ㅎ
# 2         흥부찜닭-신촌점  재료 상태도 좋고 맛도 적당히 매콤해서 좋아요 당면도 중국식당면 좋아하는디 맛있네요...
# 3         흥부찜닭-신촌점                                         맛있어요~~~~~~
# 4         흥부찜닭-신촌점                      곱창에 닭 맛있게 잘 먹었는데 양은 좀 아쉬웠습니다.
# ...            ...                                                ...
# 34520  라화쿵부마라탕-신촌점                              가게에서 먹던거랑 맛이 똑 같애요 ??
# 34521  라화쿵부마라탕-신촌점                                     11111111111111
# 34522  라화쿵부마라탕-신촌점                          국물 하고 야채 따로 따로 보장했어요.좋았어요
# 34523  라화쿵부마라탕-신촌점                                       量太少！！！！！！！！！
# 34524  라화쿵부마라탕-신촌점                                   양이 적고 덜 볶여서 맛없다.
#
#                      Address
# 0       서울 서대문구 창천동 33-43 2층
# 1       서울 서대문구 창천동 33-43 2층
# 2       서울 서대문구 창천동 33-43 2층
# 3       서울 서대문구 창천동 33-43 2층
# 4       서울 서대문구 창천동 33-43 2층
# ...                      ...
# 34520  서울 서대문구 창천동 52-5 1,2층
# 34521  서울 서대문구 창천동 52-5 1,2층
# 34522  서울 서대문구 창천동 52-5 1,2층
# 34523  서울 서대문구 창천동 52-5 1,2층
# 34524  서울 서대문구 창천동 52-5 1,2층
#
# [34525 rows x 3 columns]

# %%
yonsei_df = yonsei_df[['Restaurant', 'Address', 'Review']]
yonsei_df
# Out:
#         Restaurant                Address  \
# 0         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 1         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 2         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 3         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 4         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# ...            ...                    ...
# 34520  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34521  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34522  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34523  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34524  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
#
#                                                   Review
# 0                                       기본맛 맛있게맵고 양도 많네요
# 1                                           가성비 만족스럽네요 ㅎ
# 2      재료 상태도 좋고 맛도 적당히 매콤해서 좋아요 당면도 중국식당면 좋아하는디 맛있네요...
# 3                                             맛있어요~~~~~~
# 4                          곱창에 닭 맛있게 잘 먹었는데 양은 좀 아쉬웠습니다.
# ...                                                  ...
# 34520                              가게에서 먹던거랑 맛이 똑 같애요 ??
# 34521                                     11111111111111
# 34522                          국물 하고 야채 따로 따로 보장했어요.좋았어요
# 34523                                       量太少！！！！！！！！！
# 34524                                   양이 적고 덜 볶여서 맛없다.
#
# [34525 rows x 3 columns]

# %%
yonsei_df = yonsei_df.rename(columns={'Restaurant':'식당이름', 'Address':'주소', 'Review':'리뷰'})
yonsei_df
# Out:
#               식당이름                     주소  \
# 0         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 1         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 2         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 3         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# 4         흥부찜닭-신촌점   서울 서대문구 창천동 33-43 2층
# ...            ...                    ...
# 34520  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34521  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34522  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34523  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34524  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
#
#                                                       리뷰
# 0                                       기본맛 맛있게맵고 양도 많네요
# 1                                           가성비 만족스럽네요 ㅎ
# 2      재료 상태도 좋고 맛도 적당히 매콤해서 좋아요 당면도 중국식당면 좋아하는디 맛있네요...
# 3                                             맛있어요~~~~~~
# 4                          곱창에 닭 맛있게 잘 먹었는데 양은 좀 아쉬웠습니다.
# ...                                                  ...
# 34520                              가게에서 먹던거랑 맛이 똑 같애요 ??
# 34521                                     11111111111111
# 34522                          국물 하고 야채 따로 따로 보장했어요.좋았어요
# 34523                                       量太少！！！！！！！！！
# 34524                                   양이 적고 덜 볶여서 맛없다.
#
# [34525 rows x 3 columns]

# %%
result = pd.concat([dining_df, yonsei_df])

# %%
result
# Out:
#               식당이름                     주소  \
# 0            육회자매집     서울특별시 종로구 종로4가 177
# 1            육회자매집     서울특별시 종로구 종로4가 177
# 2            육회자매집     서울특별시 종로구 종로4가 177
# 3            육회자매집     서울특별시 종로구 종로4가 177
# 4            육회자매집     서울특별시 종로구 종로4가 177
# ...            ...                    ...
# 34520  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34521  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34522  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34523  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
# 34524  라화쿵부마라탕-신촌점  서울 서대문구 창천동 52-5 1,2층
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 34520                              가게에서 먹던거랑 맛이 똑 같애요 ??
# 34521                                     11111111111111
# 34522                          국물 하고 야채 따로 따로 보장했어요.좋았어요
# 34523                                       量太少！！！！！！！！！
# 34524                                   양이 적고 덜 볶여서 맛없다.
#
# [97369 rows x 3 columns]

# %%
kyunghee_df = pd.read_csv('./경희대.csv', encoding='cp949')
kyunghee_df.drop(['Column1', 'UserID', 'Menu', 'Total', 'Taste', 'Quantity', 'Delivery', 'Date', 'OperationTime'], axis='columns', inplace=True)
kyunghee_df = kyunghee_df[['Restaurant', 'Address', 'Review']]
kyunghee_df = kyunghee_df.rename(columns={'Restaurant':'식당이름', 'Address':'주소', 'Review':'리뷰'})
kyunghee_df
# Out:
#                  식당이름                     주소  \
# 0      백종원의인생설렁탕-경희대점   서울 동대문구 회기동 42-84 1층
# 1      백종원의인생설렁탕-경희대점   서울 동대문구 회기동 42-84 1층
# 2      백종원의인생설렁탕-경희대점   서울 동대문구 회기동 42-84 1층
# 3      백종원의인생설렁탕-경희대점   서울 동대문구 회기동 42-84 1층
# 4      백종원의인생설렁탕-경희대점   서울 동대문구 회기동 42-84 1층
# ...               ...                    ...
# 12877        CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12878        CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12879        CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12880        CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12881        CU-경희스타점  서울 동대문구 회기동 42-141 1층
#
#                                                       리뷰
# 0                                    생각보다 배달이 빨라서 놀랐어요~!
# 1                                            맛있고 깔끔해요.추천
# 2                                          너무너무 맛있어요 화이팅
# 3                           잘먹었습니다!! 고기 추가 추천드려용 너무 마싯어욤
# 4      소금이 너무 부족해서 밍밍한 설렁탕이였고 문앞에두면 문자달라고 했는데 문자도 안와서...
# ...                                                  ...
# 12877          빠짐없이 잘 받았습니다. 서비스로 주신 레모나도 잘 먹었어요. 감사합니다!
# 12878                  사과가 저번엔 맛있었는데 이번엔 아니네요 복불복이 심한가봐요
# 12879                                     집에서 배달도 되고 좋네요
# 12880                              잘받았습니다 사과도 먹을수있고 좋네요ㅎ
# 12881                                       배달도 빠르고 깔끔해요
#
# [12882 rows x 3 columns]

# %%
result = pd.concat([result, kyunghee_df])
result
# Out:
#            식당이름                     주소  \
# 0         육회자매집     서울특별시 종로구 종로4가 177
# 1         육회자매집     서울특별시 종로구 종로4가 177
# 2         육회자매집     서울특별시 종로구 종로4가 177
# 3         육회자매집     서울특별시 종로구 종로4가 177
# 4         육회자매집     서울특별시 종로구 종로4가 177
# ...         ...                    ...
# 12877  CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12878  CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12879  CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12880  CU-경희스타점  서울 동대문구 회기동 42-141 1층
# 12881  CU-경희스타점  서울 동대문구 회기동 42-141 1층
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 12877          빠짐없이 잘 받았습니다. 서비스로 주신 레모나도 잘 먹었어요. 감사합니다!
# 12878                  사과가 저번엔 맛있었는데 이번엔 아니네요 복불복이 심한가봐요
# 12879                                     집에서 배달도 되고 좋네요
# 12880                              잘받았습니다 사과도 먹을수있고 좋네요ㅎ
# 12881                                       배달도 빠르고 깔끔해요
#
# [110251 rows x 3 columns]

# %%
konkuk_df = pd.read_csv('./건국대.csv', encoding='cp949')
konkuk_df.drop(['Column1', 'UserID', 'Menu', 'Total', 'Taste', 'Quantity', 'Delivery', 'Date', 'OperationTime'], axis='columns', inplace=True)
konkuk_df = konkuk_df[['Restaurant', 'Address', 'Review']]
konkuk_df = konkuk_df.rename(columns={'Restaurant':'식당이름', 'Address':'주소', 'Review':'리뷰'})
konkuk_df
# Out:
#                  식당이름                        주소  \
# 0      준이네닭발&싸군통닭-송정점   서울 성동구 송정동 73-920 1층 2호
# 1      준이네닭발&싸군통닭-송정점   서울 성동구 송정동 73-920 1층 2호
# 2      준이네닭발&싸군통닭-송정점   서울 성동구 송정동 73-920 1층 2호
# 3      준이네닭발&싸군통닭-송정점   서울 성동구 송정동 73-920 1층 2호
# 4      준이네닭발&싸군통닭-송정점   서울 성동구 송정동 73-920 1층 2호
# ...               ...                       ...
# 48992          나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48993          나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48994          나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48995          나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48996          나혼자강식당  서울 광진구 화양동 478-2 1층 102호
#
#                                                       리뷰
# 0                                             맛있었어용~~~~~
# 1                                 콩나물도 많이 주시고 맛있게 잘먹었습니당
# 2                                       넘넘 맛있어요 맵기도 딱 취저
# 3                                       ????너무맛있어요.맛집이예요
# 4      오늘 3번째 입니다 ㅋㅋㅋ 새벽에 진짜 너무 땡겨서 시켜먹었어요! 두 번째 때 맨 ...
# ...                                                  ...
# 48992                        고기가 매우 퍽퍽하고 쌈장을 찍어야 맛이 나요..
# 48993                                    맛도괜찮고 양도괜찮은거같아용
# 48994                     와우 리뷰 잘안쓰는데 너무맛잇게먹어서 씁니다!!강추!!
# 48995          배달 주문 빠트리고 배달 늦게오고.. 리더기 불량이네요 총체적 난국입니다.
# 48996  이집은 맛집입니다!! 고기굽기,육즙, 쌈장,고추까지 다 맛있게 잘먹었습니다^^ 또 ...
#
# [48997 rows x 3 columns]

# %%
result = pd.concat([result, konkuk_df])
result
# Out:
#          식당이름                        주소  \
# 0       육회자매집        서울특별시 종로구 종로4가 177
# 1       육회자매집        서울특별시 종로구 종로4가 177
# 2       육회자매집        서울특별시 종로구 종로4가 177
# 3       육회자매집        서울특별시 종로구 종로4가 177
# 4       육회자매집        서울특별시 종로구 종로4가 177
# ...       ...                       ...
# 48992  나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48993  나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48994  나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48995  나혼자강식당  서울 광진구 화양동 478-2 1층 102호
# 48996  나혼자강식당  서울 광진구 화양동 478-2 1층 102호
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 48992                        고기가 매우 퍽퍽하고 쌈장을 찍어야 맛이 나요..
# 48993                                    맛도괜찮고 양도괜찮은거같아용
# 48994                     와우 리뷰 잘안쓰는데 너무맛잇게먹어서 씁니다!!강추!!
# 48995          배달 주문 빠트리고 배달 늦게오고.. 리더기 불량이네요 총체적 난국입니다.
# 48996  이집은 맛집입니다!! 고기굽기,육즙, 쌈장,고추까지 다 맛있게 잘먹었습니다^^ 또 ...
#
# [159248 rows x 3 columns]

# %%
catholic_df = pd.read_csv('./가톨릭.csv', encoding='cp949')
catholic_df.drop(['Column1', 'UserID', 'Menu', 'Total', 'Taste', 'Quantity', 'Delivery', 'Date', 'OperationTime'], axis='columns', inplace=True)
catholic_df = catholic_df[['Restaurant', 'Address', 'Review']]
catholic_df = catholic_df.rename(columns={'Restaurant':'식당이름', 'Address':'주소', 'Review':'리뷰'})
catholic_df
# Out:
#               식당이름                                   주소  \
# 0      이디야커피-한성대역점  서울 성북구 동소문동1가 90 김내과빌딩 지하1층, 1층, 2층
# 1      이디야커피-한성대역점  서울 성북구 동소문동1가 90 김내과빌딩 지하1층, 1층, 2층
# 2      이디야커피-한성대역점  서울 성북구 동소문동1가 90 김내과빌딩 지하1층, 1층, 2층
# 3      이디야커피-한성대역점  서울 성북구 동소문동1가 90 김내과빌딩 지하1층, 1층, 2층
# 4      이디야커피-한성대역점  서울 성북구 동소문동1가 90 김내과빌딩 지하1층, 1층, 2층
# ...            ...                                  ...
# 26096     피자에땅-돈암점                     서울 성북구 동소문동4가 42
# 26097     피자에땅-돈암점                     서울 성북구 동소문동4가 42
# 26098     피자에땅-돈암점                     서울 성북구 동소문동4가 42
# 26099     피자에땅-돈암점                     서울 성북구 동소문동4가 42
# 26100     피자에땅-돈암점                     서울 성북구 동소문동4가 42
#
#                                                       리뷰
# 0               배달하다 커피를 많이 쏟아서 별점 뺐어요 싸고 맛있어서 자주 주문합니다.
# 1      이디야 프레즐이 먹고싶어서 커피랑 시켰어요 너무 맛있어요 같이시킨 다른 빵종류도 맛...
# 2                                           첫주문 감사합니다 성공
# 3                                             ??????????
# 4                                                   좋아요~
# ...                                                  ...
# 26096  가격대비 대만족합니다. 맛도 좋구요. 요즘 다른 피자집들 슬금슬금 가격 올려서요. ...
# 26097                      뭘 먹을까 고민하다 시켰었는데 생각보다 맛이 죽여요ㅎ
# 26098                     일단 배달이 빨랐고 피자도 따뜻하게 와서 정말좋았습니다
# 26099                                                  ㅎ
# 26100                                         맛있게 잘먹었씀다.
#
# [26101 rows x 3 columns]

# %%
result = pd.concat([result, catholic_df])
result
# Out:
#            식당이름                  주소  \
# 0         육회자매집  서울특별시 종로구 종로4가 177
# 1         육회자매집  서울특별시 종로구 종로4가 177
# 2         육회자매집  서울특별시 종로구 종로4가 177
# 3         육회자매집  서울특별시 종로구 종로4가 177
# 4         육회자매집  서울특별시 종로구 종로4가 177
# ...         ...                 ...
# 26096  피자에땅-돈암점    서울 성북구 동소문동4가 42
# 26097  피자에땅-돈암점    서울 성북구 동소문동4가 42
# 26098  피자에땅-돈암점    서울 성북구 동소문동4가 42
# 26099  피자에땅-돈암점    서울 성북구 동소문동4가 42
# 26100  피자에땅-돈암점    서울 성북구 동소문동4가 42
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 26096  가격대비 대만족합니다. 맛도 좋구요. 요즘 다른 피자집들 슬금슬금 가격 올려서요. ...
# 26097                      뭘 먹을까 고민하다 시켰었는데 생각보다 맛이 죽여요ㅎ
# 26098                     일단 배달이 빨랐고 피자도 따뜻하게 와서 정말좋았습니다
# 26099                                                  ㅎ
# 26100                                         맛있게 잘먹었씀다.
#
# [185349 rows x 3 columns]

# %%
mg_df = pd.read_csv('./review_draft.csv')
mg_df.drop(['REV_CREATE_DATE', 'REV_POINT'], axis='columns', inplace=True)
#mg_df = mg_df[['Restaurant', 'Address', 'Review']]
mg_df = mg_df.rename(columns={'RES_NAME':'식당이름', 'RES_ADDRESS':'주소', 'REV_COMMENT':'리뷰'})
mg_df
# Out:
#         식당이름                                          주소  \
# 0       또순이네  서울특별시 영등포구 선유로47길 16\n지번 서울시 영등포구 양평동4가 81
# 1       또순이네  서울특별시 영등포구 선유로47길 16\n지번 서울시 영등포구 양평동4가 81
# 2       또순이네  서울특별시 영등포구 선유로47길 16\n지번 서울시 영등포구 양평동4가 81
# 3       또순이네  서울특별시 영등포구 선유로47길 16\n지번 서울시 영등포구 양평동4가 81
# 4       또순이네  서울특별시 영등포구 선유로47길 16\n지번 서울시 영등포구 양평동4가 81
# ...      ...                                         ...
# 102560  노랑통닭  서울특별시 동작구 상도로 274-1\n지번 서울시 동작구 상도1동 746-1
# 102561  노랑통닭  서울특별시 동작구 상도로 274-1\n지번 서울시 동작구 상도1동 746-1
# 102562  노랑통닭  서울특별시 동작구 상도로 274-1\n지번 서울시 동작구 상도1동 746-1
# 102563  카페알파      서울특별시 동작구 흑석로 24\n지번 서울시 동작구 상도동 7-136
# 102564  카페알파      서울특별시 동작구 흑석로 24\n지번 서울시 동작구 상도동 7-136
#
#                                                        리뷰
# 0       증정 꼬북칩을 사기위해 두루마리휴지를 사가는 인간의 심리처럼 점심시간 후에는 짤없이...
# 1       서울 1등 된장찌개다. 된장찌개를 팔아서 건물을 세웠다고 하는데 그정도면 말 다하지...
# 2       날씨가 추워져 급 따뜻한 된장이 아닌 정말 뜨끈~뜨끈~~한 된장찌개가 땡겨 찾아간 ...
# 3       ❤️새해복 많이 받으세용❤️\n고기는 맛이 없는데 된장찌개는\n인생 최고의 집이는 ...
# 4       토시살이랑 된장이 유명한 선유도역 음식점이다. 된장 꽤 맛있다. 맛집이라고 멀리서 ...
# ...                                                   ...
# 102560  매장에서 먹은적은 없는 집\n항상 배달시켜 먹는다\n보통은 후라이드 순살로 먹는다\...
# 102561  기대하고 갔는데 정말 실망\n순살시켰는데 무슨 부스러기같은 살만 잔뜩 주고\n치킨 ...
# 102562  늦게나와요ㅠ 튀김옷도 두껍고 튀김부스러기들이 많아서 많아보이는것이 아쉬웟네요 제스타...
# 102563  이 곳에 간다면 그 목적은 반드시 좌식 자리에 앉아 쿠션의 편안함을 느끼는 것이 되...
# 102564                        좌식자리도 있고 음료도 가격대비 양이 어마어마하다
#
# [102565 rows x 3 columns]

# %%
result = pd.concat([result, mg_df])
result
# Out:
#          식당이름                                          주소  \
# 0       육회자매집                          서울특별시 종로구 종로4가 177
# 1       육회자매집                          서울특별시 종로구 종로4가 177
# 2       육회자매집                          서울특별시 종로구 종로4가 177
# 3       육회자매집                          서울특별시 종로구 종로4가 177
# 4       육회자매집                          서울특별시 종로구 종로4가 177
# ...       ...                                         ...
# 102560   노랑통닭  서울특별시 동작구 상도로 274-1\n지번 서울시 동작구 상도1동 746-1
# 102561   노랑통닭  서울특별시 동작구 상도로 274-1\n지번 서울시 동작구 상도1동 746-1
# 102562   노랑통닭  서울특별시 동작구 상도로 274-1\n지번 서울시 동작구 상도1동 746-1
# 102563   카페알파      서울특별시 동작구 흑석로 24\n지번 서울시 동작구 상도동 7-136
# 102564   카페알파      서울특별시 동작구 흑석로 24\n지번 서울시 동작구 상도동 7-136
#
#                                                        리뷰
# 0       토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1       1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                 광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3       -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4       몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                   ...
# 102560  매장에서 먹은적은 없는 집\n항상 배달시켜 먹는다\n보통은 후라이드 순살로 먹는다\...
# 102561  기대하고 갔는데 정말 실망\n순살시켰는데 무슨 부스러기같은 살만 잔뜩 주고\n치킨 ...
# 102562  늦게나와요ㅠ 튀김옷도 두껍고 튀김부스러기들이 많아서 많아보이는것이 아쉬웟네요 제스타...
# 102563  이 곳에 간다면 그 목적은 반드시 좌식 자리에 앉아 쿠션의 편안함을 느끼는 것이 되...
# 102564                        좌식자리도 있고 음료도 가격대비 양이 어마어마하다
#
# [287914 rows x 3 columns]

# %%
mp_df = pd.read_csv('./menupan2.csv', encoding='cp949')
mp_df.columns
# Out:
# Index(['식당이름', '음식분류', '주소', 'URL', '총평점', '식당특징', '영업시간', '좌석개수', '흡연여부',
#        '인터넷유무', '주차유무', '식당설명', '리뷰', '작성날짜', '개별평점'],
#       dtype='object')

# %%
mp_df = pd.read_csv('./menupan2.csv', encoding='cp949')
mp_df.drop(['음식분류', 'URL', '총평점', '식당특징', '영업시간', '좌석개수', '흡연여부', '인터넷유무', '주차유무', '식당설명', '작성날짜', '개별평점'], axis='columns', inplace=True)
#mg_df = mg_df[['Restaurant', 'Address', 'Review']]
#mp_df = mp_df.rename(columns={'RES_NAME':'식당이름', 'RES_ADDRESS':'주소', 'REV_COMMENT':'리뷰'})
mp_df
# Out:
#                  식당이름                          주소  \
# 0      레빠쥬(les pages)  서울 강남구 신사동 506 강남출판문화센터 1층
# 1      레빠쥬(les pages)  서울 강남구 신사동 506 강남출판문화센터 1층
# 2      레빠쥬(les pages)  서울 강남구 신사동 506 강남출판문화센터 1층
# 3      레빠쥬(les pages)  서울 강남구 신사동 506 강남출판문화센터 1층
# 4      레빠쥬(les pages)  서울 강남구 신사동 506 강남출판문화센터 1층
# ...               ...                         ...
# 44205     짱구짱구꼬마김밥앤만두           서울 동대문구 휘경동 264-2
# 44206           더1980       서울 동대문구 전농동 152-19 1층
# 44207           더1980       서울 동대문구 전농동 152-19 1층
# 44208           더1980       서울 동대문구 전농동 152-19 1층
# 44209           더1980       서울 동대문구 전농동 152-19 1층
#
#                                                       리뷰
# 0                                           파스타가 괜찮은 음식점
# 1                                         감사합니다. 추천할께요^^
# 2                                        관자의 쫄길함이 살아있다..
# 3                                       이곳 파스타가 좋네요'''ㅎㅎ
# 4                                        편안한 분위기에 맛있는 집!
# ...                                                  ...
# 44205  사장님 완전 친절하시구요  둘이서 여기가서 꼬마김밥  만두  라면 시켜먹으면 완전 ...
# 44206                              보기에도 양식의 진미가 보이네요 ???
# 44207  분위기도 아기자기하고 카레가 느끼하지도 않고 정말 맛있었어요. 카레 별로 안 좋아하...
# 44208  치즈돈까스 먹었는데 치즈가 정말 듬뿍 들어있고 그렇다고 고기가 얇은 것도 아니라 정...
# 44209                              학교앞에 신상맛집이 생겼네요 기대됩니다
#
# [44210 rows x 3 columns]

# %%
result = pd.concat([result, mp_df])
result
# Out:
#               식당이름                     주소  \
# 0            육회자매집     서울특별시 종로구 종로4가 177
# 1            육회자매집     서울특별시 종로구 종로4가 177
# 2            육회자매집     서울특별시 종로구 종로4가 177
# 3            육회자매집     서울특별시 종로구 종로4가 177
# 4            육회자매집     서울특별시 종로구 종로4가 177
# ...            ...                    ...
# 44205  짱구짱구꼬마김밥앤만두      서울 동대문구 휘경동 264-2
# 44206        더1980  서울 동대문구 전농동 152-19 1층
# 44207        더1980  서울 동대문구 전농동 152-19 1층
# 44208        더1980  서울 동대문구 전농동 152-19 1층
# 44209        더1980  서울 동대문구 전농동 152-19 1층
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 44205  사장님 완전 친절하시구요  둘이서 여기가서 꼬마김밥  만두  라면 시켜먹으면 완전 ...
# 44206                              보기에도 양식의 진미가 보이네요 ???
# 44207  분위기도 아기자기하고 카레가 느끼하지도 않고 정말 맛있었어요. 카레 별로 안 좋아하...
# 44208  치즈돈까스 먹었는데 치즈가 정말 듬뿍 들어있고 그렇다고 고기가 얇은 것도 아니라 정...
# 44209                              학교앞에 신상맛집이 생겼네요 기대됩니다
#
# [332124 rows x 3 columns]

# %%
ta_df = pd.read_csv('./advisor_seoul_review_new.csv', encoding='cp949')
ta_df
# Out:
#        Column1           Column2             Column3  \
# 0      블라인드 스팟   +82 2-2076-2051      리뷰 게시 날짜: 4일 전
# 1      블라인드 스팟   +82 2-2076-2051      리뷰 게시 날짜: 4일 전
# 2      블라인드 스팟   +82 2-2076-2051      리뷰 게시 날짜: 5일 전
# 3      블라인드 스팟   +82 2-2076-2051      리뷰 게시 날짜: 5일 전
# 4      블라인드 스팟   +82 2-2076-2051      리뷰 게시 날짜: 5일 전
# ...        ...               ...                 ...
# 12558  원스인어블루문    +82 2-549-5490   2015년 1월 18일에 작성.
# 12559  원스인어블루문    +82 2-549-5490   2015년 1월 11일에 작성.
# 12560  원스인어블루문    +82 2-549-5490    2015년 1월 6일에 작성.
# 12561  원스인어블루문    +82 2-549-5490    2014년 7월 3일에 작성.
# 12562  원스인어블루문    +82 2-549-5490    2014년 6월 2일에 작성.
#
#                                                  Column4 Column5
# 0       애프터눈티세트 예약하고 방문했습니다. 찻잔과 트레이  접시가 이뻐서 앉자마자 기분...      50
# 1       여심저격 비주얼이 다 한 곳. 타 호텔에 비해 저렴한 가격에 애프터눈 티세트를 즐...      40
# 2       애프터눈티세트로 예약했는데 완전 만족스러웠습니다! 직원분들도 친절하셨고 로비가 너...      50
# 3       예쁜 비쥬얼에 트레이 구성도 하나하나 맛있어서 너무 즐거운 시간 보냈습니다 ♡ 3...      50
# 4       너무 예뻐서 사진찍을때 잘나와요! 1층부터 먹으면 된다던데 그냥 본인먹고싶은대로 ...      50
# ...                                                  ...     ...
# 12558   이것은 뉴욕 스타일 재즈 클럽도 뉴욕 가격. 좋은  단단한 음식과 좋은 와인과 재...      50
# 12559   우리는 기회를 여러 라이브 공연 에서는 재즈 바 년 중 최고였어요. 로컬 음식도 ...      40
# 12560   여기에 가서 데이트 나의 약혼녀. 은  위대한 재즈 음악  맛있는 이탈리아 음식 ...      50
# 12561   블루 재즈 바 / 레스토랑 에 잘 모르 는 문 남쪽 의 Aphujeong 로데오 ...      50
# 12562   이것 이 두번째 이 재즈 바. 라이브 음악 은. 서비스 는 좋 았습니다. 음료수가...      50
#
# [12563 rows x 5 columns]

# %%
ta_df = pd.read_csv('./advisor_seoul_review_new.csv', encoding='cp949')
ta_df.drop(['Column2', 'Column3', 'Column5'], axis='columns', inplace=True)
ta_df = ta_df.rename(columns={'Column1':'식당이름', 'Column4':'리뷰'})
ta_df
# Out:
#           식당이름                                                 리뷰
# 0      블라인드 스팟   애프터눈티세트 예약하고 방문했습니다. 찻잔과 트레이  접시가 이뻐서 앉자마자 기분...
# 1      블라인드 스팟   여심저격 비주얼이 다 한 곳. 타 호텔에 비해 저렴한 가격에 애프터눈 티세트를 즐...
# 2      블라인드 스팟   애프터눈티세트로 예약했는데 완전 만족스러웠습니다! 직원분들도 친절하셨고 로비가 너...
# 3      블라인드 스팟   예쁜 비쥬얼에 트레이 구성도 하나하나 맛있어서 너무 즐거운 시간 보냈습니다 ♡ 3...
# 4      블라인드 스팟   너무 예뻐서 사진찍을때 잘나와요! 1층부터 먹으면 된다던데 그냥 본인먹고싶은대로 ...
# ...        ...                                                ...
# 12558  원스인어블루문   이것은 뉴욕 스타일 재즈 클럽도 뉴욕 가격. 좋은  단단한 음식과 좋은 와인과 재...
# 12559  원스인어블루문   우리는 기회를 여러 라이브 공연 에서는 재즈 바 년 중 최고였어요. 로컬 음식도 ...
# 12560  원스인어블루문   여기에 가서 데이트 나의 약혼녀. 은  위대한 재즈 음악  맛있는 이탈리아 음식 ...
# 12561  원스인어블루문   블루 재즈 바 / 레스토랑 에 잘 모르 는 문 남쪽 의 Aphujeong 로데오 ...
# 12562  원스인어블루문   이것 이 두번째 이 재즈 바. 라이브 음악 은. 서비스 는 좋 았습니다. 음료수가...
#
# [12563 rows x 2 columns]

# %%
result = pd.concat([result, ta_df])
result
# Out:
#           식당이름                  주소  \
# 0        육회자매집  서울특별시 종로구 종로4가 177
# 1        육회자매집  서울특별시 종로구 종로4가 177
# 2        육회자매집  서울특별시 종로구 종로4가 177
# 3        육회자매집  서울특별시 종로구 종로4가 177
# 4        육회자매집  서울특별시 종로구 종로4가 177
# ...        ...                 ...
# 12558  원스인어블루문                 NaN
# 12559  원스인어블루문                 NaN
# 12560  원스인어블루문                 NaN
# 12561  원스인어블루문                 NaN
# 12562  원스인어블루문                 NaN
#
#                                                       리뷰
# 0      토요일 저녁 피크 시간에 갔는데 15분 정도 기다리고 먹은 것 같아요 3호점은 안 ...
# 1      1호점은 화장실이 없고 화장실은 2호점에 있음. 음식이 빨리 제공되며 맛은 일품.가...
# 2                광장시장내 육회집이구요생각보다 사람정말많아요육회는정말맛있어요 강추입니다
# 3      -아마 서울에서 육회로 가장 유명한 곳 중 하나가 아닐까?- 오랜만에 광장시장에 방...
# 4      몇년전에 줄서서 먹었던 기억이 있어 다시 갔는데 그 때보단 맛있게 먹진 않았어요. ...
# ...                                                  ...
# 12558   이것은 뉴욕 스타일 재즈 클럽도 뉴욕 가격. 좋은  단단한 음식과 좋은 와인과 재...
# 12559   우리는 기회를 여러 라이브 공연 에서는 재즈 바 년 중 최고였어요. 로컬 음식도 ...
# 12560   여기에 가서 데이트 나의 약혼녀. 은  위대한 재즈 음악  맛있는 이탈리아 음식 ...
# 12561   블루 재즈 바 / 레스토랑 에 잘 모르 는 문 남쪽 의 Aphujeong 로데오 ...
# 12562   이것 이 두번째 이 재즈 바. 라이브 음악 은. 서비스 는 좋 았습니다. 음료수가...
#
# [344687 rows x 3 columns]

# %%
result.to_csv('review_final2.csv')
